# %% [markdown]
# # Reading data

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\weather_data1.csv")

# %%
df
# Out:
#            City  Temperature_C  Humidity_% Condition
# 0      Hyderbad           28.0        60.0     Sunny
# 1    Vijayawada           29.0        62.0     Sunny
# 2  Viskhapatnam            NaN        58.0    Cloudy
# 3      Kakinada           31.0        55.0    Cloudy
# 4      Banglore            NaN        57.0     Rainy
# 5        Mumbai           33.0         NaN     Rainy
# 6       Chennai           34.0        61.0     Sunny
# 7    Rajamundry           32.0        63.0    Cloudy
# 8         Eluru            NaN        64.0     Rainy
# 9    Anakapalli           29.0        62.0     Sunny

# %% [markdown]
# # Missing values

# %%
df.isnull().sum()
# Out:
# City             0
# Temperature_C    3
# Humidity_%       1
# Condition        0
# dtype: int64

# %%
df_clean = df.dropna

# %%
df_clean
# Out:
# <bound method DataFrame.dropna of            City  Temperature_C  Humidity_% Condition
# 0      Hyderbad           28.0        60.0     Sunny
# 1    Vijayawada           29.0        62.0     Sunny
# 2  Viskhapatnam            NaN        58.0    Cloudy
# 3      Kakinada           31.0        55.0    Cloudy
# 4      Banglore            NaN        57.0     Rainy
# 5        Mumbai           33.0         NaN     Rainy
# 6       Chennai           34.0        61.0     Sunny
# 7    Rajamundry           32.0        63.0    Cloudy
# 8         Eluru            NaN        64.0     Rainy
# 9    Anakapalli           29.0        62.0     Sunny>

# %%
df =pd.read_csv(r"C:\Users\user\Downloads\weather_data1.csv")
df
# Out:
#            City  Temperature_C  Humidity_% Condition
# 0      Hyderbad           28.0        60.0     Sunny
# 1    Vijayawada           29.0        62.0     Sunny
# 2  Viskhapatnam            NaN        58.0    Cloudy
# 3      Kakinada           31.0        55.0    Cloudy
# 4      Banglore            NaN        57.0     Rainy
# 5        Mumbai           33.0         NaN     Rainy
# 6       Chennai           34.0        61.0     Sunny
# 7    Rajamundry           32.0        63.0    Cloudy
# 8         Eluru            NaN        64.0     Rainy
# 9    Anakapalli           29.0        62.0     Sunny

# %%
df
# Out:
#            City  Temperature_C  Humidity_% Condition
# 0      Hyderbad           28.0        60.0     Sunny
# 1    Vijayawada           29.0        62.0     Sunny
# 2  Viskhapatnam            NaN        58.0    Cloudy
# 3      Kakinada           31.0        55.0    Cloudy
# 4      Banglore            NaN        57.0     Rainy
# 5        Mumbai           33.0         NaN     Rainy
# 6       Chennai           34.0        61.0     Sunny
# 7    Rajamundry           32.0        63.0    Cloudy
# 8         Eluru            NaN        64.0     Rainy
# 9    Anakapalli           29.0        62.0     Sunny

# %%
df["Temperature_C"]=df["Temperature_C"].fillna(0)

# %%
df
# Out:
#            City  Temperature_C  Humidity_% Condition
# 0      Hyderbad           28.0        60.0     Sunny
# 1    Vijayawada           29.0        62.0     Sunny
# 2  Viskhapatnam            0.0        58.0    Cloudy
# 3      Kakinada           31.0        55.0    Cloudy
# 4      Banglore            0.0        57.0     Rainy
# 5        Mumbai           33.0         NaN     Rainy
# 6       Chennai           34.0        61.0     Sunny
# 7    Rajamundry           32.0        63.0    Cloudy
# 8         Eluru            0.0        64.0     Rainy
# 9    Anakapalli           29.0        62.0     Sunny

# %%
df["Temperature_C"]=df["Temperature_C"].fillna(df.Temperature_C.mean())

# %%
df
# Out:
#            City  Temperature_C  Humidity_% Condition
# 0      Hyderbad           28.0        60.0     Sunny
# 1    Vijayawada           29.0        62.0     Sunny
# 2  Viskhapatnam            0.0        58.0    Cloudy
# 3      Kakinada           31.0        55.0    Cloudy
# 4      Banglore            0.0        57.0     Rainy
# 5        Mumbai           33.0         NaN     Rainy
# 6       Chennai           34.0        61.0     Sunny
# 7    Rajamundry           32.0        63.0    Cloudy
# 8         Eluru            0.0        64.0     Rainy
# 9    Anakapalli           29.0        62.0     Sunny

# %%
df["Humidity_%"]=df["Humidity_%"].fillna(df["Humidity_%"].mean())

# %%
df
# Out:
#            City  Temperature_C  Humidity_% Condition
# 0      Hyderbad           28.0        60.0     Sunny
# 1    Vijayawada           29.0        62.0     Sunny
# 2  Viskhapatnam            0.0        58.0    Cloudy
# 3      Kakinada           31.0        55.0    Cloudy
# 4      Banglore            0.0        57.0     Rainy
# 5        Mumbai           33.0         0.0     Rainy
# 6       Chennai           34.0        61.0     Sunny
# 7    Rajamundry           32.0        63.0    Cloudy
# 8         Eluru            0.0        64.0     Rainy
# 9    Anakapalli           29.0        62.0     Sunny
