# %%
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[1,2,3,4,5,6]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.append(7)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l.insert(1,8)
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6, 7]

# %%
l.pop()
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6]

# %%
l.pop(1)
print(l)
# Out:
# [1, 3, 4, 5, 6]

# %%
l.remove(5)
print(l)
# Out:
# [1, 3, 4, 6]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.append(12)
print(l1)
# Out:
# [1, 2, 3, 12]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.extend(l2)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.clear()
print(l)
# Out:
# []

# %%
l=[1,5,8,6,7,4,]
l.sort()
print(l)
# Out:
# [1, 4, 5, 6, 7, 8]

# %%
l=[1,2,3,4,5]
l.reverse()
print(l)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# Dictionary

# %%
d={}
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
d={"name":"suji","city":"kakinada"}
print(d)
# Out:
# {'name': 'suji', 'city': 'kakinada'}

# %%
print(d["name"])
# Out:
# suji

# %%
d["mobile_number"]=123456789
print(d)
# Out:
# {'name': 'suji', 'city': 'kakinada', 'mobile_number': 123456789}

# %%
d["city"]="Hyd"
print(d)
# Out:
# {'name': 'suji', 'city': 'Hyd', 'mobile_number': 123456789}

# %%
print(d.keys())
# Out:
# dict_keys(['name', 'city', 'mobile_number'])

# %%
print(d.values())
# Out:
# dict_values(['suji', 'Hyd', 123456789])

# %%
print(d.items())
# Out:
# dict_items([('name', 'suji'), ('city', 'Hyd'), ('mobile_number', 123456789)])

# %%
f = open('abc.txt','w')
print('File name : ',f.name)
print('File Mode : ',f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# File name :  abc.txt
# File Mode :  w
# False
# True
# False
# True

# %%
with open("abc.txt","r") as file:
    content = file.read()
print(content)
# Out:
# Aditya degree college
# kakinada
# andhra pradesh

# %%
with open("abc.txt","r") as file:
    content = file.readline()
print(content)
# Out:
# Aditya degree college

# %%
with open("abc.txt","r") as file:
    content = file.readlines()
print(content)
# Out:
# ['Aditya degree college\n', 'kakinada\n', 'andhra pradesh']
