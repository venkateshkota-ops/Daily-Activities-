# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\study_marks.csv")
df
# Out:
#    Study_Hours  Marks
# 0          2.9   27.0
# 1          5.8   61.0
# 2          4.7   45.0
# 3          4.0   38.0
# 4          1.8   19.0
# 5          1.8    8.0
# 6          1.3    4.0
# 7          5.3   50.0
# 8          4.0   35.0
# 9          4.5   47.0

# %%
df.cov()
# Out:
#              Study_Hours       Marks
# Study_Hours     2.481000   28.906667
# Marks          28.906667  348.711111

# %%
df.corr()
# Out:
#              Study_Hours    Marks
# Study_Hours      1.00000  0.98277
# Marks            0.98277  1.00000

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\user\Downloads\temp_icecream_sales.csv")
df
# Out:
#    Temperature  IceCream_Sales
# 0           20             200
# 1           22             220
# 2           24             250
# 3           26             270
# 4           28             300
# 5           30             320
# 6           32             350
# 7           34             370
# 8           36             400
# 9           38             420

# %%
df.cov()
# Out:
#                 Temperature  IceCream_Sales
# Temperature       36.666667      455.555556
# IceCream_Sales   455.555556     5666.666667

# %%
df.corr()
# Out:
#            rain     sales
# rain   1.000000 -0.962092
# sales -0.962092  1.000000

# %%
data = {
    "rain": [30,32,29,35,33],
    "sales": [150,130,200,80,100]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    rain  sales
# 0    30    150
# 1    32    130
# 2    29    200
# 3    35     80
# 4    33    100

# %%
df.cov()
# Out:
#         rain   sales
# rain     5.7  -107.0
# sales -107.0  2170.0

# %%
df.corr()
# Out:
#            rain     sales
# rain   1.000000 -0.962092
# sales -0.962092  1.000000

# %%
data = {
    "speed": [40,60,85,100,200],
    "distance": [700,300,500,400,500]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    speed  distance
# 0     40       700
# 1     60       300
# 2     85       500
# 3    100       400
# 4    200       500

# %%
df.cov()
# Out:
#            speed  distance
# speed     3845.0   -1075.0
# distance -1075.0   22000.0

# %%
df.corr
# Out:
# <bound method DataFrame.corr of    speed  distance
# 0     40       700
# 1     60       300
# 2     85       500
# 3    100       400
# 4    200       500>

# %% [markdown]
# # normalization

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
s = pd.Series([1000,2000,3000,5000,9000])
s
# Out:
# 0    1000
# 1    2000
# 2    3000
# 3    5000
# 4    9000
# dtype: int64

# %%
s.max()
# Out:
# 9000

# %%
s.min
# Out:
# <bound method Series.min of 0    1000
# 1    2000
# 2    3000
# 3    5000
# 4    9000
# dtype: int64>

# %%
s_norm = (s - s.min()) / (s.max() - s.min())
print(s_norm)
# Out:
# 0    0.000
# 1    0.125
# 2    0.250
# 3    0.500
# 4    1.000
# dtype: float64

# %%
s_norm = MinMaxScaler().fit_transform(s.values.reshape(-1,1))
print(s_norm)
# Out:
# [[0.   ]
#  [0.125]
#  [0.25 ]
#  [0.5  ]
#  [1.   ]]

# %%
df = pd.DataFrame({
    "Temp": [20,25,30,35,40],
    "Humidity": [30,45,60,70,90]
})
df
# Out:
#    Temp  Humidity
# 0    20        30
# 1    25        45
# 2    30        60
# 3    35        70
# 4    40        90

# %%
norm_data = MinMaxScaler().fit_transform(df)
norm_data
# Out:
# array([[0.        , 0.        ],
#        [0.25      , 0.25      ],
#        [0.5       , 0.5       ],
#        [0.75      , 0.66666667],
#        [1.        , 1.        ]])

# %%
norm_df = pd.DataFrame(norm_data, columns=df.columns)
norm_df
# Out:
#    Temp  Humidity
# 0  0.00  0.000000
# 1  0.25  0.250000
# 2  0.50  0.500000
# 3  0.75  0.666667
# 4  1.00  1.000000

# %% [markdown]
# # Standardization

# %%
s = pd.Series([1000,2000,3000,5000,9000])
s
# Out:
# 0    1000
# 1    2000
# 2    3000
# 3    5000
# 4    9000
# dtype: int64

# %%
s.mean()
# Out:
# 4000.0

# %%
s.std()
# Out:
# 3162.2776601683795

# %%
z_Score=(s - s.mean()) / s.std()
print(z_Score)
# Out:
# 0   -0.948683
# 1   -0.632456
# 2   -0.316228
# 3    0.316228
# 4    1.581139
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
z_Score = StandardScaler().fit_transform(s.values.reshape(-1,1))
print(z_Score)
# Out:
# [[-1.06066017]
#  [-0.70710678]
#  [-0.35355339]
#  [ 0.35355339]
#  [ 1.76776695]]

# %%
z_Score = (s - s.mean()) / s.std(ddof=0)
print(z_Score)
# Out:
# 0   -1.060660
# 1   -0.707107
# 2   -0.353553
# 3    0.353553
# 4    1.767767
# dtype: float64

# %%
df = pd.DataFrame({
    "Temp": [20,25,30,35,40],
    "Humidity": [30,45,60,70,90]
})
df
# Out:
#    Temp  Humidity
# 0    20        30
# 1    25        45
# 2    30        60
# 3    35        70
# 4    40        90

# %%
z_Score = StandardScaler().fit_transform(df)
z_Score_df = pd.DataFrame(z_Score, columns=df.columns)
print(z_Score)
# Out:
# [[-1.41421356 -1.4083645 ]
#  [-0.70710678 -0.6799001 ]
#  [ 0.          0.04856429]
#  [ 0.70710678  0.53420722]
#  [ 1.41421356  1.50549309]]
